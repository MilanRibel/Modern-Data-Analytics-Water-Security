# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Load dataset

# %%
df=pd.read_csv("2021_Cities_Water_Security_Risks.csv")
print("Dimension of data frame:", df.shape)
df.head(20)
# Out:
# Dimension of data frame: (2349, 15)
#    Questionnaire Name  Account Number                   Account Name  \
# 0         Cities 2021            1093            City of Atlanta, GA
# 1         Cities 2021            1093            City of Atlanta, GA
# 2         Cities 2021            1184             City of Austin, TX
# 3         Cities 2021            1499        Ajuntament de Barcelona
# 4         Cities 2021            1499        Ajuntament de Barcelona
# 5         Cities 2021            1499        Ajuntament de Barcelona
# 6         Cities 2021            1499        Ajuntament de Barcelona
# 7         Cities 2021            1499        Ajuntament de Barcelona
# 8         Cities 2021            1499        Ajuntament de Barcelona
# 9         Cities 2021            1499        Ajuntament de Barcelona
# 10        Cities 2021            1499        Ajuntament de Barcelona
# 11        Cities 2021            1499        Ajuntament de Barcelona
# 12        Cities 2021            1850        Birmingham City Council
# 13        Cities 2021            2185           Bristol City Council
# 14        Cities 2021            2430         City of Burlington, VT
# 15        Cities 2021            2621  Cambridgeshire County Council
# 16        Cities 2021            3203            City of Chicago, IL
# 17        Cities 2021            3417              New York City, NY
# 18        Cities 2021            3422       Greater London Authority
# 19        Cities 2021            3422       Greater London Authority
#
#                                               Country     CDP Region  \
# 0                            United States of America  North America
# 1                            United States of America  North America
# 2                            United States of America  North America
# 3                                               Spain         Europe
# 4                                               Spain         Europe
# 5                                               Spain         Europe
# 6                                               Spain         Europe
# 7                                               Spain         Europe
# 8                                               Spain         Europe
# 9                                               Spain         Europe
# 10                                              Spain         Europe
# 11                                              Spain         Europe
# 12  United Kingdom of Great Britain and Northern I...         Europe
# 13  United Kingdom of Great Britain and Northern I...         Europe
# 14                           United States of America  North America
# 15  United Kingdom of Great Britain and Northern I...         Europe
# 16                           United States of America  North America
# 17                           United States of America  North America
# 18  United Kingdom of Great Britain and Northern I...         Europe
# 19  United Kingdom of Great Britain and Northern I...         Europe
#
#          ParentSection       Section Question Number  \
# 0   14. Water Security  Water Supply           14.2a
# 1   14. Water Security  Water Supply           14.2a
# 2   14. Water Security  Water Supply           14.2a
# 3   14. Water Security  Water Supply           14.2a
# 4   14. Water Security  Water Supply           14.2a
# 5   14. Water Security  Water Supply           14.2a
# 6   14. Water Security  Water Supply           14.2a
# 7   14. Water Security  Water Supply           14.2a
# 8   14. Water Security  Water Supply           14.2a
# 9   14. Water Security  Water Supply           14.2a
# 10  14. Water Security  Water Supply           14.2a
# 11  14. Water Security  Water Supply           14.2a
# 12  14. Water Security  Water Supply           14.2a
# 13  14. Water Security  Water Supply           14.2a
# 14  14. Water Security  Water Supply           14.2a
# 15  14. Water Security  Water Supply           14.2a
# 16  14. Water Security  Water Supply           14.2a
# 17  14. Water Security  Water Supply           14.2a
# 18  14. Water Security  Water Supply           14.2a
# 19  14. Water Security  Water Supply           14.2a
#
#                                         Question Name  Row Number  \
# 0   Please identify the risks to your city’s water...           1
# 1   Please identify the risks to your city’s water...           2
# 2   Please identify the risks to your city’s water...           1
# 3   Please identify the risks to your city’s water...           1
# 4   Please identify the risks to your city’s water...           2
# 5   Please identify the risks to your city’s water...           3
# 6   Please identify the risks to your city’s water...           4
# 7   Please identify the risks to your city’s water...           5
# 8   Please identify the risks to your city’s water...           6
# 9   Please identify the risks to your city’s water...           7
# 10  Please identify the risks to your city’s water...           8
# 11  Please identify the risks to your city’s water...           9
# 12  Please identify the risks to your city’s water...           0
# 13  Please identify the risks to your city’s water...           0
# 14  Please identify the risks to your city’s water...           0
# 15  Please identify the risks to your city’s water...           1
# 16  Please identify the risks to your city’s water...           0
# 17  Please identify the risks to your city’s water...           1
# 18  Please identify the risks to your city’s water...           1
# 19  Please identify the risks to your city’s water...           2
#
#                          Water security risk drivers    Anticipated timescale  \
# 0                             Increased water stress     Short-term (by 2025)
# 1                                Higher water prices                  Current
# 2                             Increased water stress     Short-term (by 2025)
# 3                             Increased water stress                  Current
# 4                            Declining water quality    Medium-term (by 2050)
# 5                              Severe weather events                  Current
# 6                           Increased water scarcity                  Current
# 7                             Increased water demand                  Current
# 8                                            Drought                  Current
# 9                                Higher water prices                  Current
# 10                           Declining water quality                  Current
# 11                           Declining water quality                  Current
# 12                           Question not applicable  Question not applicable
# 13                           Question not applicable  Question not applicable
# 14                           Question not applicable  Question not applicable
# 15                            Increased water demand     Short-term (by 2025)
# 16                           Question not applicable  Question not applicable
# 17  Inadequate or ageing water supply infrastructure                  Current
# 18                            Increased water stress     Short-term (by 2025)
# 19                            Increased water stress   Long-term (after 2050)
#
#    Estimated magnitude of potential impact Estimated probability of impact  \
# 0                                  Serious                             NaN
# 1                                  Serious                             NaN
# 2                        Extremely serious                            High
# 3                                  Serious                     Medium-high
# 4                             Less Serious                          Medium
# 5                                  Serious                     Medium-high
# 6                                  Serious                     Medium-high
# 7                             Less Serious                      Medium-low
# 8                                  Serious                     Medium-high
# 9                                  Serious                     Medium-high
# 10                                 Serious                            High
# 11                                 Serious                            High
# 12                 Question not applicable         Question not applicable
# 13                 Question not applicable         Question not applicable
# 14                 Question not applicable         Question not applicable
# 15                       Extremely serious                            High
# 16                 Question not applicable         Question not applicable
# 17                                 Serious                             NaN
# 18                                 Serious                     Medium-high
# 19                                 Serious                            High
#
#                                      Risk description
# 0   The city depends on one river for water supply...
# 1   The water cost burden is felt across all ZIP c...
# 2   Central Texas is drought prone and we depend o...
# 3   The downscaling of the climate projections at ...
# 4   A reduction in water resources availability  c...
# 5   In terms of water supply, rivers floods could ...
# 6   Climate Plan vulnerability assessement showed ...
# 7   Climate Plan vulnerability assessement showed ...
# 8   The city currently has a deficit in its water ...
# 9   Barcelona’s adhesion to the Blue Communities n...
# 10  Bathing water quality improvement, ongoing LIF...
# 11  Reduction of pollution at origen. Sewer sociol...
# 12                            Question not applicable
# 13                            Question not applicable
# 14                            Question not applicable
# 15  increased growth without a secure water supply...
# 16                            Question not applicable
# 17  New York City’s drinking water meets orexceeds...
# 18  Short term drought risk is significant. The im...
# 19  In the medium to longer term, London is foreca...

# %%
#view more columns
pd.set_option('display.max_columns', 100)

# %%
df.dtypes
# Out:
# Questionnaire Name                         object
# Account Number                              int64
# Account Name                               object
# Country                                    object
# CDP Region                                 object
# ParentSection                              object
# Section                                    object
# Question Number                            object
# Question Name                              object
# Row Number                                  int64
# Water security risk drivers                object
# Anticipated timescale                      object
# Estimated magnitude of potential impact    object
# Estimated probability of impact            object
# Risk description                           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Questionnaire Name                       2349 non-null   object
#  1   Account Number                           2349 non-null   int64
#  2   Account Name                             2349 non-null   object
#  3   Country                                  2349 non-null   object
#  4   CDP Region                               2349 non-null   object
#  5   ParentSection                            2349 non-null   object
#  6   Section                                  2349 non-null   object
#  7   Question Number                          2349 non-null   object
#  8   Question Name                            2349 non-null   object
#  9   Row Number                               2349 non-null   int64
#  10  Water security risk drivers              2137 non-null   object
#  11  Anticipated timescale                    2152 non-null   object
#  12  Estimated magnitude of potential impact  2088 non-null   object
#  13  Estimated probability of impact          1755 non-null   object
#  14  Risk description                         1944 non-null   object
# dtypes: int64(2), object(13)
# memory usage: 275.4+ KB

# %%
#check for missing and categorical values
for i in list(df.columns):
    print(f'{i} {sum(df[i].isnull())} nulls and {df[i].nunique()} unique values ')
# Out:
# Questionnaire Name 0 nulls and 1 unique values
# Account Number 0 nulls and 1070 unique values
# Account Name 0 nulls and 1070 unique values
# Country 0 nulls and 93 unique values
# CDP Region 0 nulls and 8 unique values
# ParentSection 0 nulls and 1 unique values
# Section 0 nulls and 1 unique values
# Question Number 0 nulls and 1 unique values
# Question Name 0 nulls and 1 unique values
# Row Number 0 nulls and 161 unique values
# Water security risk drivers 212 nulls and 64 unique values
# Anticipated timescale 197 nulls and 5 unique values
# Estimated magnitude of potential impact 261 nulls and 4 unique values
# Estimated probability of impact 594 nulls and 7 unique values
# Risk description 405 nulls and 1368 unique values

# %% [markdown]
# ## Heatmap of missing values

# %%
plt.figure(figsize = (18, 6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
#plt.xlabel(xlabel = 'CDP Region', fontsize = 20)
#plt.ylabel(ylabel = 'Value', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=20)
#plt.xticks(rotation=90)
#plt.legend(loc = 'best', fontsize = 20)

# %%
# Top 5 countries with most entries
plt.figure(figsize = (10, 6))
sns.countplot(x = 'Country', data = df, order = df['Country'].value_counts().head().index)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
# Top 5 cities with most entries
plt.figure(figsize = (14, 8))
sns.countplot(x = 'Account Name', data = df, order = df['Account Name'].value_counts().head().index)
# Out:
# <AxesSubplot:xlabel='Account Name', ylabel='count'>

# %%
#countplot based on regions
sns.set(font_scale = 1.25)
plt.figure(figsize = (18, 8))
regions = sns.countplot(x = 'CDP Region', data = df)
plt.xlabel(xlabel = 'CDP Region', fontsize = 20)
plt.ylabel(ylabel = 'Count', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xticks(rotation=90)
#plt.legend(fontsize = 15)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'North America'),
#   Text(1, 0, 'Europe'),
#   Text(2, 0, 'Southeast Asia and Oceania'),
#   Text(3, 0, 'East Asia'),
#   Text(4, 0, 'Africa'),
#   Text(5, 0, 'Latin America'),
#   Text(6, 0, 'South and West Asia'),
#   Text(7, 0, 'Middle East')])

# %%
#countplot based on regions with hue Estimated magnitude of potential impact
plt.figure(figsize = (18, 9))
plt.legend(loc="upper right", frameon=True, fontsize=20)
ax = sns.countplot(x = 'CDP Region', data = df, hue = 'Estimated magnitude of potential impact')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xticks(rotation=45)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'North America'),
#   Text(1, 0, 'Europe'),
#   Text(2, 0, 'Southeast Asia and Oceania'),
#   Text(3, 0, 'East Asia'),
#   Text(4, 0, 'Africa'),
#   Text(5, 0, 'Latin America'),
#   Text(6, 0, 'South and West Asia'),
#   Text(7, 0, 'Middle East')])

# %%
#countplot based on regions with hue Estimated probability of impact
plt.figure(figsize = (18, 10))
sns.countplot(x = 'CDP Region', data = df,
              hue = 'Estimated probability of impact')
# Out:
# <AxesSubplot:xlabel='CDP Region', ylabel='count'>

# %%
#countplot based on regions with hue Anticipated timescale
plt.figure(figsize = (18, 10))
sns.countplot(x = 'CDP Region', data = df,
              hue = 'Anticipated timescale')
# Out:
# <AxesSubplot:xlabel='CDP Region', ylabel='count'>

# %% [markdown]
# ## Get fractional value for each cdp region
# Here, for each region, we try to get the fraction of categories in the categorical variables 'Estimated magnitude of potential impact', 'Estimated probability of impact' and 'Anticipated timescale'

# %%
def percent_frac(x): #x = estimated_prob/etc
    
    
    data = pd.read_csv("2021_Cities_Water_Security_Risks.csv")
    
    data_1 = data[['CDP Region', x]].dropna()
    
    # remove rows with question not available
    
    new_data = data_1[data_1[x] != 'Question not applicable']
    
    locations = list(new_data['CDP Region'].unique())
    severities = list(new_data[x].dropna().unique())
    
        
    # now get percentage
    length = []
    percent_frac = []
    for i in locations:
        data_frame = new_data[new_data['CDP Region'] == i]
        size = len(data_frame)
        length.append(size)
        for j in severities:
            new_df = data_frame[data_frame[x] == j]
            percent_frac.append(len(new_df)/size)
    new_per = np.array(percent_frac).reshape(len(locations), len(severities))
    
    
    #how many columns? no of unicities
    
    no_columns = len(severities)
    
    new_df = pd.DataFrame(data = new_per, columns = severities)
    new_df['CDP Region'] = locations
    
    new_pd = pd.melt(new_df, id_vars='CDP Region',
        value_vars=list(new_data[x].dropna().unique()))
    new_pd.rename(columns = {'variable':x}, inplace = True)        
        
    return new_pd
    
    # length of each data

# %%
prob_impact = percent_frac('Estimated probability of impact')
mag_impact = percent_frac('Estimated magnitude of potential impact')
time_scale = percent_frac('Anticipated timescale') #x = estimated_prob/etc

# %%
plt.figure(figsize = (18, 10))
sns.barplot(data = prob_impact, x = 'CDP Region', y = 'value', hue = 'Estimated probability of impact')
# Out:
# <AxesSubplot:xlabel='CDP Region', ylabel='value'>

# %%
plt.figure(figsize = (18, 8))
sns.barplot(data = mag_impact, x = 'CDP Region', y = 'value', hue = 'Estimated magnitude of potential impact')
# Out:
# <AxesSubplot:xlabel='CDP Region', ylabel='value'>

# %%
plt.figure(figsize = (18, 8))
sns.barplot(data = time_scale, x = 'CDP Region', y = 'value', hue = 'Anticipated timescale')
plt.xlabel(xlabel = 'CDP Region', fontsize = 20)
plt.ylabel(ylabel = 'Value', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xticks(rotation=90)
plt.ylim([0, 0.65])
plt.legend(fontsize = 20)

# %% [markdown]
# ## Fracton value of not reported

# %%
# check fraction of missing data for each region

def miss_fraction(x):
    df = x[['Account Number', 'CDP Region','Water security risk drivers',
       'Anticipated timescale', 'Estimated magnitude of potential impact',
       'Estimated probability of impact', 'Risk description']]
    columns = ['Water security risk drivers',
       'Anticipated timescale', 'Estimated magnitude of potential impact',
       'Estimated probability of impact', 'Risk description']
    
    location = list(df['CDP Region'].unique())
    
    length = []
    percent_frac = []
    
    for i in location:
        data_frame = df[df['CDP Region'] == i]
        size = len(data_frame)
        length.append(size)
        for j in columns:
            value = sum(data_frame[j].isna())
            percent_frac.append(value/size)
    new_per = np.array(percent_frac).reshape(len(location), len(columns))
    
    #how many columns? no of unicities
    
    no_columns = len(columns)
    
    new_df = pd.DataFrame(data = new_per, columns = columns)
    new_df['CDP Region'] = location
    
    new_pd = pd.melt(new_df, id_vars='CDP Region',
        value_vars=columns)
    new_pd.rename(columns = {'variable':'description'}, inplace = True)
    
    return new_pd

# %%
missing = miss_fraction(df)

# %%
plt.figure(figsize = (18, 6))
#plt.legend(loc="best", frameon=True, fontsize=20)
sns.barplot(data = missing, x = 'CDP Region', y = 'value', hue = 'description')
plt.xlabel(xlabel = 'CDP Region', fontsize = 20)
plt.ylabel(ylabel = 'Value', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xticks(rotation=90)
plt.ylim([0, 0.8])
plt.legend(fontsize = 15)

# %%
sns.barplot(x="CDP Region", y="value", hue = 'description', data=missing)
# Out:
# <AxesSubplot:xlabel='CDP Region', ylabel='value'>

# %%
dfs = df[df['CDP Region'] == 'South and West Asia']

# %%
new_pd = pd.melt(missing, id_vars='CDP Region',
        value_vars=['Water security risk drivers',
       'Anticipated timescale', 'Estimated magnitude of potential impact',
       'Estimated probability of impact', 'Risk description'])

# %%
new_pd
# Out:
#                     CDP Region                                 variable  \
# 0                North America              Water security risk drivers
# 1                       Europe              Water security risk drivers
# 2   Southeast Asia and Oceania              Water security risk drivers
# 3                    East Asia              Water security risk drivers
# 4                       Africa              Water security risk drivers
# 5                Latin America              Water security risk drivers
# 6          South and West Asia              Water security risk drivers
# 7                  Middle East              Water security risk drivers
# 8                North America                    Anticipated timescale
# 9                       Europe                    Anticipated timescale
# 10  Southeast Asia and Oceania                    Anticipated timescale
# 11                   East Asia                    Anticipated timescale
# 12                      Africa                    Anticipated timescale
# 13               Latin America                    Anticipated timescale
# 14         South and West Asia                    Anticipated timescale
# 15                 Middle East                    Anticipated timescale
# 16               North America  Estimated magnitude of potential impact
# 17                      Europe  Estimated magnitude of potential impact
# 18  Southeast Asia and Oceania  Estimated magnitude of potential impact
# 19                   East Asia  Estimated magnitude of potential impact
# 20                      Africa  Estimated magnitude of potential impact
# 21               Latin America  Estimated magnitude of potential impact
# 22         South and West Asia  Estimated magnitude of potential impact
# 23                 Middle East  Estimated magnitude of potential impact
# 24               North America          Estimated probability of impact
# 25                      Europe          Estimated probability of impact
# 26  Southeast Asia and Oceania          Estimated probability of impact
# 27                   East Asia          Estimated probability of impact
# 28                      Africa          Estimated probability of impact
# 29               Latin America          Estimated probability of impact
# 30         South and West Asia          Estimated probability of impact
# 31                 Middle East          Estimated probability of impact
# 32               North America                         Risk description
# 33                      Europe                         Risk description
# 34  Southeast Asia and Oceania                         Risk description
# 35                   East Asia                         Risk description
# 36                      Africa                         Risk description
# 37               Latin America                         Risk description
# 38         South and West Asia                         Risk description
# 39                 Middle East                         Risk description
#
#        value
# 0   0.011062
# 1   0.025761
# 2   0.419178
# 3   0.012000
# 4   0.062500
# 5   0.036683
# 6   0.106383
# 7   0.095238
# 8   0.008850
# 9   0.021077
# 10  0.416438
# 11  0.032000
# 12  0.037500
# 13  0.020734
# 14  0.042553
# 15  0.142857
# 16  0.053097
# 17  0.046838
# 18  0.435616
# 19  0.012000
# 20  0.075000
# 21  0.046252
# 22  0.170213
# 23  0.285714
# 24  0.238938
# 25  0.166276
# 26  0.504110
# 27  0.036000
# 28  0.343750
# 29  0.216906
# 30  0.489362
# 31  0.380952
# 32  0.037611
# 33  0.145199
# 34  0.457534
# 35  0.128000
# 36  0.162500
# 37  0.138756
# 38  0.191489
# 39  0.238095

# %%
prob_impact = percent_frac('Estimated probability of impact')
mag_impact = percent_frac('Estimated magnitude of potential impact')
time_scale = percent_frac('Anticipated timescale') #x = estimated_prob/etc

# %%
plt.figure(figsize = (18, 10))
sns.barplot(data = time_scale, x = 'CDP Region', y = 'value', hue = 'Anticipated timescale')
# Out:
# <AxesSubplot:xlabel='CDP Region', ylabel='value'>

# %%
plt.figure(figsize = (18, 10))
sns.barplot(data = mag_impact, x = 'CDP Region', y = 'value', hue = 'Estimated magnitude of potential impact')
# Out:
# <AxesSubplot:xlabel='CDP Region', ylabel='value'>

# %%
plt.figure(figsize = (18, 10))
sns.barplot(data = prob_impact, x = 'CDP Region', y = 'value', hue = 'Estimated probability of impact')
# Out:
# <AxesSubplot:xlabel='CDP Region', ylabel='value'>

# %%
pop_data = pd.read_csv('2021_City-wide_Emissions.csv')

# %%
to_concat = pop_data[['Account Number','Land area (in square km)', 'Population']]

# %%
concated_data = pd.merge(df, to_concat, left_on = 'Account Number', right_on = 'Account Number', how = 'left')

concated_data.head()
# Out:
#   Questionnaire Name  Account Number             Account Name  \
# 0        Cities 2021            1093      City of Atlanta, GA
# 1        Cities 2021            1093      City of Atlanta, GA
# 2        Cities 2021            1184       City of Austin, TX
# 3        Cities 2021            1499  Ajuntament de Barcelona
# 4        Cities 2021            1499  Ajuntament de Barcelona
#
#                     Country     CDP Region       ParentSection       Section  \
# 0  United States of America  North America  14. Water Security  Water Supply
# 1  United States of America  North America  14. Water Security  Water Supply
# 2  United States of America  North America  14. Water Security  Water Supply
# 3                     Spain         Europe  14. Water Security  Water Supply
# 4                     Spain         Europe  14. Water Security  Water Supply
#
#   Question Number                                      Question Name  \
# 0           14.2a  Please identify the risks to your city’s water...
# 1           14.2a  Please identify the risks to your city’s water...
# 2           14.2a  Please identify the risks to your city’s water...
# 3           14.2a  Please identify the risks to your city’s water...
# 4           14.2a  Please identify the risks to your city’s water...
#
#    Row Number Water security risk drivers  Anticipated timescale  \
# 0           1      Increased water stress   Short-term (by 2025)
# 1           2         Higher water prices                Current
# 2           1      Increased water stress   Short-term (by 2025)
# 3           1      Increased water stress                Current
# 4           2     Declining water quality  Medium-term (by 2050)
#
#   Estimated magnitude of potential impact Estimated probability of impact  \
# 0                                 Serious                             NaN
# 1                                 Serious                             NaN
# 2                       Extremely serious                            High
# 3                                 Serious                     Medium-high
# 4                            Less Serious                          Medium
#
#                                     Risk description  \
# 0  The city depends on one river for water supply...
# 1  The water cost burden is felt across all ZIP c...
# 2  Central Texas is drought prone and we depend o...
# 3  The downscaling of the climate projections at ...
# 4  A reduction in water resources availability  c...
#
#    Land area (in square km)  Population
# 0                    347.00    506811.0
# 1                    347.00    506811.0
# 2                    845.70    995484.0
# 3                    102.15   1664182.0
# 4                    102.15   1664182.0

# %%
concated_data['Population Density'] = round(concated_data['Population']/concated_data['Land area (in square km)'])

# %%
concated_data.head()
# Out:
#   Questionnaire Name  Account Number             Account Name  \
# 0        Cities 2021            1093      City of Atlanta, GA
# 1        Cities 2021            1093      City of Atlanta, GA
# 2        Cities 2021            1184       City of Austin, TX
# 3        Cities 2021            1499  Ajuntament de Barcelona
# 4        Cities 2021            1499  Ajuntament de Barcelona
#
#                     Country     CDP Region       ParentSection       Section  \
# 0  United States of America  North America  14. Water Security  Water Supply
# 1  United States of America  North America  14. Water Security  Water Supply
# 2  United States of America  North America  14. Water Security  Water Supply
# 3                     Spain         Europe  14. Water Security  Water Supply
# 4                     Spain         Europe  14. Water Security  Water Supply
#
#   Question Number                                      Question Name  \
# 0           14.2a  Please identify the risks to your city’s water...
# 1           14.2a  Please identify the risks to your city’s water...
# 2           14.2a  Please identify the risks to your city’s water...
# 3           14.2a  Please identify the risks to your city’s water...
# 4           14.2a  Please identify the risks to your city’s water...
#
#    Row Number Water security risk drivers  Anticipated timescale  \
# 0           1      Increased water stress   Short-term (by 2025)
# 1           2         Higher water prices                Current
# 2           1      Increased water stress   Short-term (by 2025)
# 3           1      Increased water stress                Current
# 4           2     Declining water quality  Medium-term (by 2050)
#
#   Estimated magnitude of potential impact Estimated probability of impact  \
# 0                                 Serious                             NaN
# 1                                 Serious                             NaN
# 2                       Extremely serious                            High
# 3                                 Serious                     Medium-high
# 4                            Less Serious                          Medium
#
#                                     Risk description  \
# 0  The city depends on one river for water supply...
# 1  The water cost burden is felt across all ZIP c...
# 2  Central Texas is drought prone and we depend o...
# 3  The downscaling of the climate projections at ...
# 4  A reduction in water resources availability  c...
#
#    Land area (in square km)  Population  Population Density
# 0                    347.00    506811.0              1461.0
# 1                    347.00    506811.0              1461.0
# 2                    845.70    995484.0              1177.0
# 3                    102.15   1664182.0             16292.0
# 4                    102.15   1664182.0             16292.0

# %%
concated_data[concated_data['Account Name'] == "Tarakan City"]
# Out:
#      Questionnaire Name  Account Number  Account Name    Country  \
# 1470        Cities 2021           73750  Tarakan City  Indonesia
# 1471        Cities 2021           73750  Tarakan City  Indonesia
# 1472        Cities 2021           73750  Tarakan City  Indonesia
# 1473        Cities 2021           73750  Tarakan City  Indonesia
# 1474        Cities 2021           73750  Tarakan City  Indonesia
# ...                 ...             ...           ...        ...
# 1625        Cities 2021           73750  Tarakan City  Indonesia
# 1626        Cities 2021           73750  Tarakan City  Indonesia
# 1627        Cities 2021           73750  Tarakan City  Indonesia
# 1628        Cities 2021           73750  Tarakan City  Indonesia
# 1629        Cities 2021           73750  Tarakan City  Indonesia
#
#                       CDP Region       ParentSection       Section  \
# 1470  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1471  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1472  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1473  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1474  Southeast Asia and Oceania  14. Water Security  Water Supply
# ...                          ...                 ...           ...
# 1625  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1626  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1627  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1628  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1629  Southeast Asia and Oceania  14. Water Security  Water Supply
#
#      Question Number                                      Question Name  \
# 1470           14.2a  Please identify the risks to your city’s water...
# 1471           14.2a  Please identify the risks to your city’s water...
# 1472           14.2a  Please identify the risks to your city’s water...
# 1473           14.2a  Please identify the risks to your city’s water...
# 1474           14.2a  Please identify the risks to your city’s water...
# ...              ...                                                ...
# 1625           14.2a  Please identify the risks to your city’s water...
# 1626           14.2a  Please identify the risks to your city’s water...
# 1627           14.2a  Please identify the risks to your city’s water...
# 1628           14.2a  Please identify the risks to your city’s water...
# 1629           14.2a  Please identify the risks to your city’s water...
#
#       Row Number                       Water security risk drivers  \
# 1470           1                                           Drought
# 1471           2                            Increased water demand
# 1472           3                           Declining water quality
# 1473           4  Inadequate or ageing water supply infrastructure
# 1474           5                               Higher water prices
# ...          ...                                               ...
# 1625         156                                               NaN
# 1626         157                                               NaN
# 1627         158                                               NaN
# 1628         159                                               NaN
# 1629         160                                               NaN
#
#      Anticipated timescale Estimated magnitude of potential impact  \
# 1470  Short-term (by 2025)                                 Serious
# 1471               Current                                 Serious
# 1472               Current                                 Serious
# 1473  Short-term (by 2025)                                 Serious
# 1474  Short-term (by 2025)                                 Serious
# ...                    ...                                     ...
# 1625                   NaN                                     NaN
# 1626                   NaN                                     NaN
# 1627                   NaN                                     NaN
# 1628                   NaN                                     NaN
# 1629                   NaN                                     NaN
#
#      Estimated probability of impact                      Risk description  \
# 1470                     Medium-high  forest fire, water scarcity, drought
# 1471                     Medium-high                   service not maximum
# 1472                          Medium            affect to community health
# 1473                            High    increasing NRW (non revenue water)
# 1474                            High              operational cost is high
# ...                              ...                                   ...
# 1625                             NaN                                   NaN
# 1626                             NaN                                   NaN
# 1627                             NaN                                   NaN
# 1628                             NaN                                   NaN
# 1629                             NaN                                   NaN
#
#       Land area (in square km)  Population  Population Density
# 1470                     250.8    245784.0               980.0
# 1471                     250.8    245784.0               980.0
# 1472                     250.8    245784.0               980.0
# 1473                     250.8    245784.0               980.0
# 1474                     250.8    245784.0               980.0
# ...                        ...         ...                 ...
# 1625                     250.8    245784.0               980.0
# 1626                     250.8    245784.0               980.0
# 1627                     250.8    245784.0               980.0
# 1628                     250.8    245784.0               980.0
# 1629                     250.8    245784.0               980.0
#
# [160 rows x 18 columns]

# %%
full_data = pd.read_csv('2021_Full_Cities_Dataset.csv')

# %%
full_data.head()
# Out:
#   Questionnaire  Year Reported to CDP  Account Number  \
# 0   Cities 2021                  2021          841964
# 1   Cities 2021                  2021           54652
# 2   Cities 2021                  2021          859188
# 3   Cities 2021                  2021           60319
# 4   Cities 2021                  2021           54342
#
#                    Organization                   Country  \
# 0  City of Hallandale Beach, FL  United States of America
# 1          Prefeitura de Osasco                    Brazil
# 2                Kirishima City                     Japan
# 3     Prefeitura de Pato Branco                    Brazil
# 4     Jbail-Byblos Municipality                   Lebanon
#
#                  CDP Region                        Parent Section  \
# 0  United States of America  2. Climate Hazards and Vulnerability
# 1             Latin America  2. Climate Hazards and Vulnerability
# 2                 East Asia                5. Emissions Reduction
# 3             Latin America                5. Emissions Reduction
# 4               Middle East                4. City-wide Emissions
#
#                         Section Question Number  \
# 0               Climate Hazards             2.1
# 1               Climate Hazards             2.2
# 2            Mitigation Actions             5.4
# 3     Mitigation Target setting            5.0d
# 4  City-wide GHG Emissions Data            4.6a
#
#                                        Question Name  Column Number  \
# 0  Please list the most significant climate hazar...              6
# 1  Please identify and describe the factors that ...              1
# 2  Describe the anticipated outcomes of the most ...             20
# 3  Please provide details of your total city-wide...              5
# 4  The Global Covenant of Mayors requires committ...              1
#
#                                         Column Name  Row Number  \
# 0  Most relevant assets / services affected overall           4
# 1              Factors that affect ability to adapt           3
# 2                           Role in the GCC program          14
# 3                                         Base year           0
# 4             Direct emissions (metric tonnes CO2e)          30
#
#                                    Row Name          Response Answer Comments  \
# 0                                       NaN            Public health      NaN
# 1                                       NaN      Access to education      NaN
# 2                                       NaN  Question not applicable      NaN
# 3                                       NaN  Question not applicable      NaN
# 4  Total Generation of grid-supplied energy  Question not applicable      NaN
#
#   File Name             Last update
# 0       NaN  05/06/2022 05:42:33 AM
# 1       NaN  05/06/2022 05:42:33 AM
# 2       NaN  05/06/2022 05:42:33 AM
# 3       NaN  05/06/2022 05:42:33 AM
# 4       NaN  05/06/2022 05:42:33 AM

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1636446 entries, 0 to 1636445
# Data columns (total 18 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Questionnaire         1636446 non-null  object
#  1   Year Reported to CDP  1636446 non-null  int64
#  2   Account Number        1636446 non-null  int64
#  3   Organization          1636446 non-null  object
#  4   Country               1636446 non-null  object
#  5   CDP Region            1569382 non-null  object
#  6   Parent Section        1220487 non-null  object
#  7   Section               1636446 non-null  object
#  8   Question Number       1636446 non-null  object
#  9   Question Name         1636446 non-null  object
#  10  Column Number         1636446 non-null  int64
#  11  Column Name           1590891 non-null  object
#  12  Row Number            1636446 non-null  int64
#  13  Row Name              788170 non-null   object
#  14  Response Answer       1300967 non-null  object
#  15  Comments              28853 non-null    object
#  16  File Name             3512 non-null     object
#  17  Last update           1636446 non-null  object
# dtypes: int64(4), object(14)
# memory usage: 224.7+ MB

# %%
#check for missing and categorical values
for i in list(full_data.columns):
    print(f'{i} {sum(full_data[i].isnull())} nulls and {full_data[i].nunique()} unique values ')
# Out:
# Questionnaire 0 nulls and 1 unique values
# Year Reported to CDP 0 nulls and 1 unique values
# Account Number 0 nulls and 1070 unique values
# Organization 0 nulls and 1070 unique values
# Country 0 nulls and 93 unique values
# CDP Region 67064 nulls and 9 unique values
# Parent Section 415959 nulls and 9 unique values
# Section 0 nulls and 32 unique values
# Question Number 0 nulls and 150 unique values
# Question Name 0 nulls and 150 unique values
# Column Number 0 nulls and 24 unique values
# Column Name 45555 nulls and 375 unique values
# Row Number 0 nulls and 168 unique values
# Row Name 848276 nulls and 169 unique values
# Response Answer 335479 nulls and 115289 unique values
# Comments 1607593 nulls and 1712 unique values
# File Name 1632934 nulls and 2960 unique values
# Last update 0 nulls and 1 unique values

# %%
full_data[full_data['Section'] == 'Water Supply Management']
# Out:
# City-wide GHG Emissions Data                      346427
# 10. Transport                                     186661
# Mitigation Actions                                179008
# Climate Hazards                                   122794
# Mitigation Target setting                         105012
# 8. Energy                                         100636
# Adaptation Actions                                 96019
# 12. Food                                           59048
# GCoM Emission Factor and Activity Data             46108
# Finance and Economic Opportunities                 39737
# 13. Waste                                          37450
# Local Government Operations GHG Emissions Data     33562
# Governance                                         33358
# Adaptation Planning                                30876
# Adaptation Goals                                   28881
# Climate Risk and Vulnerability Assessment          27742
# Mitigation Planning                                25891
# 9. Buildings                                       24674
# Water Supply Management                            16123
# Historical emissions inventories                   15837
# Water Supply                                       15486
# Collaboration                                      12098
# Opportunities                                      11229
# City Details                                        9630
# Climate Action Planning                             7517
# Local Government Emissions Verification             6420
# Adaptation Planning Process                         5382
# City-wide external verification                     4280
# 11. Urban Planning                                  3210
# 0. Introduction                                     3210
# Data Management                                     1070
# Submit your response                                1070
# Name: Section, dtype: int64

# %%
full_data[full_data['Section'] == 'Adaptation Actions'].head()
# Out:
#    Questionnaire  Year Reported to CDP  Account Number  \
# 13   Cities 2021                  2021           35885
# 26   Cities 2021                  2021           17411
# 29   Cities 2021                  2021          841269
# 71   Cities 2021                  2021           73724
# 99   Cities 2021                  2021           35475
#
#                        Organization  \
# 13       Tel Aviv-Yafo Municipality
# 26  Southend on Sea Borough Council
# 29      Municipalidad de Montecarlo
# 71                          Arteaga
# 99              City of Calgary, AB
#
#                                               Country     CDP Region  \
# 13                                             Israel    Middle East
# 26  United Kingdom of Great Britain and Northern I...         Europe
# 29                                          Argentina  Latin America
# 71                                          Argentina  Latin America
# 99                                             Canada            NaN
#
#    Parent Section             Section Question Number  \
# 13  3. Adaptation  Adaptation Actions             3.0
# 26  3. Adaptation  Adaptation Actions             3.0
# 29  3. Adaptation  Adaptation Actions             3.0
# 71  3. Adaptation  Adaptation Actions             3.0
# 99  3. Adaptation  Adaptation Actions             3.0
#
#                                         Question Name  Column Number  \
# 13  Please describe the main actions you are takin...             12
# 26  Please describe the main actions you are takin...              3
# 29  Please describe the main actions you are takin...             10
# 71  Please describe the main actions you are takin...              6
# 99  Please describe the main actions you are takin...              4
#
#                                           Column Name  Row Number Row Name  \
# 13  Total cost provided by the local government (c...          13      NaN
# 26                                       Action title           5      NaN
# 29                            Majority funding source          11      NaN
# 71                                    Co-benefit area           1      NaN
# 99                                   Status of action           6      NaN
#
#                                      Response Answer Comments File Name  \
# 13                                               NaN      NaN       NaN
# 26  SARCC (Sustainable and resilient coastal cities)      NaN       NaN
# 29                                     (Sub)national      NaN       NaN
# 71          Social community and labour improvements      NaN       NaN
# 99                                         Operation      NaN       NaN
#
#                Last update
# 13  05/06/2022 05:42:33 AM
# 26  05/06/2022 05:42:33 AM
# 29  05/06/2022 05:42:33 AM
# 71  05/06/2022 05:42:33 AM
# 99  05/06/2022 05:42:33 AM

# %%
full_data['Column Number'].unique()
# Out:
# array([ 6,  1, 20,  5,  4,  2,  9, 15,  0, 12,  7, 10,  3, 13, 23,  8, 16,
#        22, 14, 18, 19, 11, 17, 21], dtype=int64)

# %%
plt.figure(figsize = (10, 6))
sns.heatmap(concated_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
predict_data = pd.read_excel('aquastat.xls')
predict_data.head()
# Out:
#           Area Area Id                                    Variable Name  \
# 0  Afghanistan       4  Total area of the country (excl. coastal water)
# 1  Afghanistan       4  Total area of the country (excl. coastal water)
# 2  Afghanistan       4  Total area of the country (excl. coastal water)
# 3  Afghanistan       4  Total area of the country (excl. coastal water)
# 4  Afghanistan       4  Total area of the country (excl. coastal water)
#
#   Variable Id    Year    Value Symbol   Md  Unnamed: 8
# 0        4100  1992.0  65286.0      X  NaN      6768.0
# 1        4100  1997.0  65286.0      X  NaN      6768.0
# 2        4100  2002.0  65286.0      X  NaN      6768.0
# 3        4100  2007.0  65286.0      X  NaN      6768.0
# 4        4100  2012.0  65286.0      X  NaN      6768.0

# %%
predict_data[predict_data['Area'] == 'Afghanistan']
# Out:
#            Area Area Id                                    Variable Name  \
# 0   Afghanistan       4  Total area of the country (excl. coastal water)
# 1   Afghanistan       4  Total area of the country (excl. coastal water)
# 2   Afghanistan       4  Total area of the country (excl. coastal water)
# 3   Afghanistan       4  Total area of the country (excl. coastal water)
# 4   Afghanistan       4  Total area of the country (excl. coastal water)
# 5   Afghanistan       4  Total area of the country (excl. coastal water)
# 6   Afghanistan       4  Total area of the country (excl. coastal water)
# 7   Afghanistan       4                                 Arable land area
# 8   Afghanistan       4                                 Arable land area
# 9   Afghanistan       4                                 Arable land area
# 10  Afghanistan       4                                 Arable land area
# 11  Afghanistan       4                                 Arable land area
# 12  Afghanistan       4                                 Arable land area
# 13  Afghanistan       4                                 Arable land area
#
#    Variable Id    Year    Value Symbol   Md  Unnamed: 8
# 0         4100  1992.0  65286.0      X  NaN      6768.0
# 1         4100  1997.0  65286.0      X  NaN      6768.0
# 2         4100  2002.0  65286.0      X  NaN      6768.0
# 3         4100  2007.0  65286.0      X  NaN      6768.0
# 4         4100  2012.0  65286.0      X  NaN      6768.0
# 5         4100  2017.0  65286.0      E  NaN         0.0
# 6         4100  2018.0  65286.0      E  NaN         0.0
# 7         4101  1992.0   7910.0      X  NaN         0.0
# 8         4101  1997.0   7685.0      X  NaN         0.0
# 9         4101  2002.0   7678.0      X  NaN         0.0
# 10        4101  2007.0   7794.0      X  NaN         0.0
# 11        4101  2012.0   7790.0      X  NaN         0.0
# 12        4101  2017.0   7699.0      X  NaN         0.0
# 13        4101  2018.0   7794.0      X  NaN         0.0

# %%
predict_data['Variable Name'].unique()
# Out:
# array(['Total area of the country (excl. coastal water)',
#        'Arable land area', nan, 'accessed on&nbsp'], dtype=object)

# %%
df[df['Account Name'] == "Tarakan City"]
# Out:
#      Questionnaire Name  Account Number  Account Name    Country  \
# 1470        Cities 2021           73750  Tarakan City  Indonesia
# 1471        Cities 2021           73750  Tarakan City  Indonesia
# 1472        Cities 2021           73750  Tarakan City  Indonesia
# 1473        Cities 2021           73750  Tarakan City  Indonesia
# 1474        Cities 2021           73750  Tarakan City  Indonesia
# ...                 ...             ...           ...        ...
# 1625        Cities 2021           73750  Tarakan City  Indonesia
# 1626        Cities 2021           73750  Tarakan City  Indonesia
# 1627        Cities 2021           73750  Tarakan City  Indonesia
# 1628        Cities 2021           73750  Tarakan City  Indonesia
# 1629        Cities 2021           73750  Tarakan City  Indonesia
#
#                       CDP Region       ParentSection       Section  \
# 1470  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1471  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1472  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1473  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1474  Southeast Asia and Oceania  14. Water Security  Water Supply
# ...                          ...                 ...           ...
# 1625  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1626  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1627  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1628  Southeast Asia and Oceania  14. Water Security  Water Supply
# 1629  Southeast Asia and Oceania  14. Water Security  Water Supply
#
#      Question Number                                      Question Name  \
# 1470           14.2a  Please identify the risks to your city’s water...
# 1471           14.2a  Please identify the risks to your city’s water...
# 1472           14.2a  Please identify the risks to your city’s water...
# 1473           14.2a  Please identify the risks to your city’s water...
# 1474           14.2a  Please identify the risks to your city’s water...
# ...              ...                                                ...
# 1625           14.2a  Please identify the risks to your city’s water...
# 1626           14.2a  Please identify the risks to your city’s water...
# 1627           14.2a  Please identify the risks to your city’s water...
# 1628           14.2a  Please identify the risks to your city’s water...
# 1629           14.2a  Please identify the risks to your city’s water...
#
#       Row Number                       Water security risk drivers  \
# 1470           1                                           Drought
# 1471           2                            Increased water demand
# 1472           3                           Declining water quality
# 1473           4  Inadequate or ageing water supply infrastructure
# 1474           5                               Higher water prices
# ...          ...                                               ...
# 1625         156                                               NaN
# 1626         157                                               NaN
# 1627         158                                               NaN
# 1628         159                                               NaN
# 1629         160                                               NaN
#
#      Anticipated timescale Estimated magnitude of potential impact  \
# 1470  Short-term (by 2025)                                 Serious
# 1471               Current                                 Serious
# 1472               Current                                 Serious
# 1473  Short-term (by 2025)                                 Serious
# 1474  Short-term (by 2025)                                 Serious
# ...                    ...                                     ...
# 1625                   NaN                                     NaN
# 1626                   NaN                                     NaN
# 1627                   NaN                                     NaN
# 1628                   NaN                                     NaN
# 1629                   NaN                                     NaN
#
#      Estimated probability of impact                      Risk description
# 1470                     Medium-high  forest fire, water scarcity, drought
# 1471                     Medium-high                   service not maximum
# 1472                          Medium            affect to community health
# 1473                            High    increasing NRW (non revenue water)
# 1474                            High              operational cost is high
# ...                              ...                                   ...
# 1625                             NaN                                   NaN
# 1626                             NaN                                   NaN
# 1627                             NaN                                   NaN
# 1628                             NaN                                   NaN
# 1629                             NaN                                   NaN
#
# [160 rows x 15 columns]

# %%
df[df['Account Name'] == "Tarakan City"]['Risk description'].value_counts().head()
# Out:
# forest fire, water scarcity, drought    1
# service not maximum                     1
# affect to community health              1
# increasing NRW (non revenue water)      1
# operational cost is high                1
# Name: Risk description, dtype: int64

# %%
df['Anticipated timescale'].value_counts().head()
# Out:
# Current                    596
# Question not applicable    512
# Medium-term (by 2050)      466
# Short-term (by 2025)       365
# Long-term (after 2050)     213
# Name: Anticipated timescale, dtype: int64

# %%
len(df[df['Account Name'] == 'Tarakan City'])
# Out:
# 160

# %%
# check no of cities with multiple entries
multiple_cities = np.unique([i for i in df['Account Name'] if len(df[df['Account Name'] == i]) > 1])

# %%
len(multiple_cities)
# Out:
# 408

# %%
#there are 408 cities with multiple rows

# %%
# first make a dataframe with only unique cities

df_unique = pd.DataFrame(columns=df.columns)
df_unique
# Out:
# Empty DataFrame
# Columns: [Questionnaire Name, Account Number, Account Name, Country, CDP Region, ParentSection, Section, Question Number, Question Name, Row Number, Water security risk drivers, Anticipated timescale, Estimated magnitude of potential impact, Estimated probability of impact, Risk description]
# Index: []

# %%
unique_cities = [i for i in list(df['Account Name']) if i not in multiple_cities]

# %%
for i in unique_cities:
    df_unique = pd.concat([df_unique, df[df['Account Name'] == i]])

# %%
df_unique.head()
# Out:
#    Questionnaire Name Account Number                   Account Name  \
# 2         Cities 2021           1184             City of Austin, TX
# 12        Cities 2021           1850        Birmingham City Council
# 13        Cities 2021           2185           Bristol City Council
# 14        Cities 2021           2430         City of Burlington, VT
# 15        Cities 2021           2621  Cambridgeshire County Council
#
#                                               Country     CDP Region  \
# 2                            United States of America  North America
# 12  United Kingdom of Great Britain and Northern I...         Europe
# 13  United Kingdom of Great Britain and Northern I...         Europe
# 14                           United States of America  North America
# 15  United Kingdom of Great Britain and Northern I...         Europe
#
#          ParentSection       Section Question Number  \
# 2   14. Water Security  Water Supply           14.2a
# 12  14. Water Security  Water Supply           14.2a
# 13  14. Water Security  Water Supply           14.2a
# 14  14. Water Security  Water Supply           14.2a
# 15  14. Water Security  Water Supply           14.2a
#
#                                         Question Name Row Number  \
# 2   Please identify the risks to your city’s water...          1
# 12  Please identify the risks to your city’s water...          0
# 13  Please identify the risks to your city’s water...          0
# 14  Please identify the risks to your city’s water...          0
# 15  Please identify the risks to your city’s water...          1
#
#    Water security risk drivers    Anticipated timescale  \
# 2       Increased water stress     Short-term (by 2025)
# 12     Question not applicable  Question not applicable
# 13     Question not applicable  Question not applicable
# 14     Question not applicable  Question not applicable
# 15      Increased water demand     Short-term (by 2025)
#
#    Estimated magnitude of potential impact Estimated probability of impact  \
# 2                        Extremely serious                            High
# 12                 Question not applicable         Question not applicable
# 13                 Question not applicable         Question not applicable
# 14                 Question not applicable         Question not applicable
# 15                       Extremely serious                            High
#
#                                      Risk description
# 2   Central Texas is drought prone and we depend o...
# 12                            Question not applicable
# 13                            Question not applicable
# 14                            Question not applicable
# 15  increased growth without a secure water supply...

# %%
#check for missing and categorical values
for i in list(df_unique.columns):
    print(f'{i} {sum(df_unique[i].isnull())} nulls and {df_unique[i].nunique()} unique values ')
# Out:
# Questionnaire Name 0 nulls and 1 unique values
# Account Number 0 nulls and 662 unique values
# Account Name 0 nulls and 662 unique values
# Country 0 nulls and 69 unique values
# CDP Region 0 nulls and 8 unique values
# ParentSection 0 nulls and 1 unique values
# Section 0 nulls and 1 unique values
# Question Number 0 nulls and 1 unique values
# Question Name 0 nulls and 1 unique values
# Row Number 0 nulls and 2 unique values
# Water security risk drivers 38 nulls and 18 unique values
# Anticipated timescale 24 nulls and 5 unique values
# Estimated magnitude of potential impact 34 nulls and 4 unique values
# Estimated probability of impact 81 nulls and 7 unique values
# Risk description 53 nulls and 164 unique values

# %%
#original missing heatmap
plt.figure(figsize = (10, 6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#unique missing heatmap
plt.figure(figsize = (10, 6))
sns.heatmap(df_unique.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# make dictionaries for categorical variables
# first

cate_columns = ['Anticipated timescale', 'Estimated magnitude of potential impact', 'Estimated probability of impact']
for i in cate_columns:
    print(df[i].unique(), '\n')
# Out:
# ['Short-term (by 2025)' 'Current' 'Medium-term (by 2050)'
#  'Question not applicable' 'Long-term (after 2050)' nan]
#
# ['Serious' 'Extremely serious' 'Less Serious' 'Question not applicable'
#  nan]
#
# [nan 'High' 'Medium-high' 'Medium' 'Medium-low' 'Question not applicable'
#  'Low' 'Do not know']

# %%
multi_city_df
# Out:
# Empty DataFrame
# Columns: [Questionnaire Name, Account Number, Account Name, Country, CDP Region, ParentSection, Section, Question Number, Question Name, Row Number, Water security risk drivers, Anticipated timescale, Estimated magnitude of potential impact, Estimated probability of impact, Risk description]
# Index: []

# %%
# now do for cities with multple entries

def multiple_cities_df(cities):
    
    #construct empty dataframe
    data_frame = pd.DataFrame(columns=list(df.columns))
    
    for i in cities:
        #we construct df for each city
        citi_data = df[df['Account Name'] == i]
        #length of data_frame for the city
        entries = len(city_data)
        
        for j in np.arange(0, entries):
            
        
    return data_frame

# %%
mult_cities = multiple_cities_df(multiple_cities)
mul

# %%
mult_cities.head()
# Out:
#      Questionnaire Name Account Number                   Account Name  \
# 1394        Cities 2021          63616  Abasan Al-Kabira Municipality
# 1395        Cities 2021          63616  Abasan Al-Kabira Municipality
# 1396        Cities 2021          63616  Abasan Al-Kabira Municipality
# 1104        Cities 2021          58485          Abington Township, PA
# 1105        Cities 2021          58485          Abington Township, PA
#
#                        Country     CDP Region       ParentSection  \
# 1394        State of Palestine    Middle East  14. Water Security
# 1395        State of Palestine    Middle East  14. Water Security
# 1396        State of Palestine    Middle East  14. Water Security
# 1104  United States of America  North America  14. Water Security
# 1105  United States of America  North America  14. Water Security
#
#            Section Question Number  \
# 1394  Water Supply           14.2a
# 1395  Water Supply           14.2a
# 1396  Water Supply           14.2a
# 1104  Water Supply           14.2a
# 1105  Water Supply           14.2a
#
#                                           Question Name Row Number  \
# 1394  Please identify the risks to your city’s water...          1
# 1395  Please identify the risks to your city’s water...          2
# 1396  Please identify the risks to your city’s water...          3
# 1104  Please identify the risks to your city’s water...          1
# 1105  Please identify the risks to your city’s water...          2
#
#                            Water security risk drivers  \
# 1394                           Declining water quality
# 1395  Inadequate or ageing water supply infrastructure
# 1396                            Increased water stress
# 1104  Inadequate or ageing water supply infrastructure
# 1105                               Higher water prices
#
#        Anticipated timescale Estimated magnitude of potential impact  \
# 1394                 Current                                 Serious
# 1395   Medium-term (by 2050)                                     NaN
# 1396    Short-term (by 2025)                                 Serious
# 1104  Long-term (after 2050)                            Less Serious
# 1105                 Current                                 Serious
#
#      Estimated probability of impact  \
# 1394                     Medium-high
# 1395                             NaN
# 1396                     Medium-high
# 1104                     Do not know
# 1105                     Do not know
#
#                                        Risk description
# 1394                                                NaN
# 1395                                                NaN
# 1396                                                NaN
# 1104  Unknown as this has not been formally assessed...
# 1105  The public water supplier AquaPA has increased...

# %%
new_mult = mult_cities.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
new_mult.info()
#check for missing and categorical values
for i in list(df_unique.columns):
    print(f'{i} {sum(new_mult[i].isnull())} nulls and {new_mult[i].nunique()} unique values ')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1016 entries, 1104 to 1710
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Questionnaire Name                       1016 non-null   object
#  1   Account Number                           1016 non-null   object
#  2   Account Name                             1016 non-null   object
#  3   Country                                  1016 non-null   object
#  4   CDP Region                               1016 non-null   object
#  5   ParentSection                            1016 non-null   object
#  6   Section                                  1016 non-null   object
#  7   Question Number                          1016 non-null   object
#  8   Question Name                            1016 non-null   object
#  9   Row Number                               1016 non-null   object
#  10  Water security risk drivers              1016 non-null   object
#  11  Anticipated timescale                    1016 non-null   object
#  12  Estimated magnitude of potential impact  1016 non-null   object
#  13  Estimated probability of impact          1016 non-null   object
#  14  Risk description                         1016 non-null   object
# dtypes: object(15)
# memory usage: 127.0+ KB
# Questionnaire Name 0 nulls and 1 unique values
# Account Number 0 nulls and 283 unique values
# Account Name 0 nulls and 283 unique values
# Country 0 nulls and 57 unique values
# CDP Region 0 nulls and 8 unique values
# ParentSection 0 nulls and 1 unique values
# Section 0 nulls and 1 unique values
# Question Number 0 nulls and 1 unique values
# Question Name 0 nulls and 1 unique values
# Row Number 0 nulls and 15 unique values
# Water security risk drivers 0 nulls and 51 unique values
# Anticipated timescale 0 nulls and 5 unique values
# Estimated magnitude of potential impact 0 nulls and 4 unique values
# Estimated probability of impact 0 nulls and 7 unique values
# Risk description 0 nulls and 895 unique values

# %%
mult_cities.info()
for i in list(df_unique.columns):
    print(f'{i} {sum(mult_cities[i].isnull())} nulls and {mult_cities[i].nunique()} unique values ')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1687 entries, 1394 to 1710
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Questionnaire Name                       1687 non-null   object
#  1   Account Number                           1687 non-null   object
#  2   Account Name                             1687 non-null   object
#  3   Country                                  1687 non-null   object
#  4   CDP Region                               1687 non-null   object
#  5   ParentSection                            1687 non-null   object
#  6   Section                                  1687 non-null   object
#  7   Question Number                          1687 non-null   object
#  8   Question Name                            1687 non-null   object
#  9   Row Number                               1687 non-null   object
#  10  Water security risk drivers              1513 non-null   object
#  11  Anticipated timescale                    1514 non-null   object
#  12  Estimated magnitude of potential impact  1460 non-null   object
#  13  Estimated probability of impact          1174 non-null   object
#  14  Risk description                         1335 non-null   object
# dtypes: object(15)
# memory usage: 210.9+ KB
# Questionnaire Name 0 nulls and 1 unique values
# Account Number 0 nulls and 408 unique values
# Account Name 0 nulls and 408 unique values
# Country 0 nulls and 70 unique values
# CDP Region 0 nulls and 8 unique values
# ParentSection 0 nulls and 1 unique values
# Section 0 nulls and 1 unique values
# Question Number 0 nulls and 1 unique values
# Question Name 0 nulls and 1 unique values
# Row Number 0 nulls and 160 unique values
# Water security risk drivers 174 nulls and 59 unique values
# Anticipated timescale 173 nulls and 5 unique values
# Estimated magnitude of potential impact 227 nulls and 4 unique values
# Estimated probability of impact 513 nulls and 7 unique values
# Risk description 352 nulls and 1205 unique values

# %%
mult_cities = multiple_cities_df(multiple_cities)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15032/2087146232.py in <module>
# ----> 1 mult_cities = multiple_cities_df(multiple_cities)
#
# ~\AppData\Local\Temp/ipykernel_15032/1998931180.py in multiple_cities_df(cities)
#      21             entry = initial_df.iloc[[i]]
#      22             # check if the row is complete
# ---> 23             if sum(entry.isnull().iloc[i]) == 0:
#      24                 #take only the first row
#      25                 complete_columns = pd.concat([complete_columns, entry])
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
mult_cities

# %%
lang = translator.translate(df['Risk description'][1], dest='en')

# %%
lang

# %%
df[df['Risk description'] == 'Question not applicable'].head()
# Out:
#    Questionnaire Name  Account Number             Account Name  \
# 12        Cities 2021            1850  Birmingham City Council
# 13        Cities 2021            2185     Bristol City Council
# 14        Cities 2021            2430   City of Burlington, VT
# 16        Cities 2021            3203      City of Chicago, IL
# 30        Cities 2021            8242       Helsingin kaupunki
#
#                                               Country     CDP Region  \
# 12  United Kingdom of Great Britain and Northern I...         Europe
# 13  United Kingdom of Great Britain and Northern I...         Europe
# 14                           United States of America  North America
# 16                           United States of America  North America
# 30                                            Finland         Europe
#
#          ParentSection       Section Question Number  \
# 12  14. Water Security  Water Supply           14.2a
# 13  14. Water Security  Water Supply           14.2a
# 14  14. Water Security  Water Supply           14.2a
# 16  14. Water Security  Water Supply           14.2a
# 30  14. Water Security  Water Supply           14.2a
#
#                                         Question Name  Row Number  \
# 12  Please identify the risks to your city’s water...           0
# 13  Please identify the risks to your city’s water...           0
# 14  Please identify the risks to your city’s water...           0
# 16  Please identify the risks to your city’s water...           0
# 30  Please identify the risks to your city’s water...           0
#
#    Water security risk drivers    Anticipated timescale  \
# 12     Question not applicable  Question not applicable
# 13     Question not applicable  Question not applicable
# 14     Question not applicable  Question not applicable
# 16     Question not applicable  Question not applicable
# 30     Question not applicable  Question not applicable
#
#    Estimated magnitude of potential impact Estimated probability of impact  \
# 12                 Question not applicable         Question not applicable
# 13                 Question not applicable         Question not applicable
# 14                 Question not applicable         Question not applicable
# 16                 Question not applicable         Question not applicable
# 30                 Question not applicable         Question not applicable
#
#            Risk description
# 12  Question not applicable
# 13  Question not applicable
# 14  Question not applicable
# 16  Question not applicable
# 30  Question not applicable
